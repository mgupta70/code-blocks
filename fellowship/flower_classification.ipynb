# %%
import numpy as np
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms
from torchvision.datasets import Flowers102
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda
from torchvision.io import read_image
from fastai.vision.all import *
from natsort import natsorted
import gc
import scipy.io
from utils import *
import cv2
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
clear_gpu_cache()
# Out:
# cuda

# %% [markdown]
# #### EDA

# %%
split = scipy.io.loadmat('official_data/setid.mat')
split
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNX86, Created on: Thu Feb 19 17:38:58 2009',
#  '__version__': '1.0',
#  '__globals__': [],
#  'trnid': array([[6765, 6755, 6768, ..., 8026, 8036, 8041]], dtype=uint16),
#  'valid': array([[6773, 6767, 6739, ..., 8028, 8008, 8030]], dtype=uint16),
#  'tstid': array([[6734, 6735, 6737, ..., 8044, 8045, 8047]], dtype=uint16)}

# %%
# Subtract 1 to make index start from 0
train_inds = split['trnid'].flatten() - 1 
val_inds = split['valid'].flatten() - 1
test_inds = split['tstid'].flatten() - 1

print('Min indexes: ', train_inds.min(), val_inds.min(), test_inds.min())
print('Max indexes: ', train_inds.max(), val_inds.max(), test_inds.max())
print('   Size    : ', train_inds.shape[0], val_inds.shape[0], test_inds.shape[0])
# Out:
# Min indexes:  27 16 0
# Max indexes:  8176 8186 8188
#    Size    :  1020 1020 6149

# %%
labels_file = scipy.io.loadmat('official_data/imagelabels.mat')
labels_file
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNX86, Created on: Thu Feb 19 15:43:33 2009',
#  '__version__': '1.0',
#  '__globals__': [],
#  'labels': array([[77, 77, 77, ..., 62, 62, 62]], dtype=uint8)}

# %%
labels = labels_file['labels']
labels = labels.flatten() - 1  # to make it start from 0 to 101
print('labels shape', labels.shape)
print('First class index: ', labels.min(), ' Last class index: ', labels.max())

train_labels = torch.from_numpy(labels[train_inds]); print(len(train_labels), 'train labels: ', train_labels)
val_labels = torch.from_numpy(labels[val_inds]); print(len(val_labels), 'val labels: ', val_labels)
test_labels = torch.from_numpy(labels[test_inds]); print(len(test_labels), 'test labels: ', test_labels)
# Out:
# labels shape (8189,)
# First class index:  0  Last class index:  101
# 1020 train labels:  tensor([  0,   0,   0,  ..., 101, 101, 101], dtype=torch.uint8)
# 1020 val labels:  tensor([  0,   0,   0,  ..., 101, 101, 101], dtype=torch.uint8)
# 6149 test labels:  tensor([  0,   0,   0,  ..., 101, 101, 101], dtype=torch.uint8)

# %%
all_files = get_image_files('official_data/102flowers/jpg/')

train_files = all_files[train_inds]; print('train_files: ', len(train_files))
val_files = all_files[val_inds]; print('val_files: ', len(val_files))
test_files = all_files[test_inds]; print('test_files: ', len(test_files))
# Out:
# train_files:  1020
# val_files:  1020
# test_files:  6149

# %%
class FlowerDataset(Dataset):
    def __init__(self, pths, targets, transform = None, target_transform = None):
        self.pths = pths
        self.targets = targets
        self.transform = transform
        self.target_transform = target_transform
        
    def __len__(self):
        return len(self.pths)
    
    def __getitem__(self, idx):
        im_pth = str(self.pths[idx])
        image = Image.fromarray(cv2.cvtColor(cv2.imread(im_pth), cv2.COLOR_BGR2RGB))
        label = self.targets[idx]
        
        if self.transform:
            image = self.transform(image)
            
        if self.target_transform:
            image = self.target_transform
            
        return image, label

# %%
to_tensor = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

invTrans = transforms.Compose([ transforms.Normalize(mean = [ 0., 0., 0. ],
                                                     std = [ 1/0.229, 1/0.224, 1/0.225 ]),
                                transforms.Normalize(mean = [ -0.485, -0.456, -0.406 ],
                                                     std = [ 1., 1., 1. ]),])

# %%
# # Pytorch In-built dataset

# train_ds = Flowers102(root = './data', split = 'train', transform= to_tensor, download= True)
# val_ds= Flowers102(root = './data', split = 'val', transform= to_tensor, download= True)
# test_ds = Flowers102(root = './data', split = 'test', transform= to_tensor, download= True)

train_ds = FlowerDataset(pths = train_files, targets= train_labels, transform=to_tensor)
val_ds = FlowerDataset(val_files, val_labels, transform=to_tensor)
test_ds = FlowerDataset(test_files, test_labels, transform=to_tensor)

bs = 32

train_loader = DataLoader(train_ds, batch_size = bs, shuffle = True)
val_loader = DataLoader(val_ds, batch_size = bs, shuffle = False)
test_loader = DataLoader(test_ds, batch_size = bs, shuffle = False)

X, y = next(iter(train_loader))
print(X.shape, y.shape)
# Out:
# torch.Size([32, 3, 224, 224]) torch.Size([32])

# %%
train_counts_dict = class_distribution_dataloader(train_loader)
val_counts_dict = class_distribution_dataloader(val_loader)
test_counts_dict =  class_distribution_dataloader(test_loader)

print('class: train: val: test')
for k in natsorted(list(train_counts_dict.keys())):
    print(f"  {k}:  {train_counts_dict[k]} : {val_counts_dict[k]} : {test_counts_dict[k]}")
# Out:
# class: train: val: test
#   0:  10 : 10 : 20
#   1:  10 : 10 : 40
#   2:  10 : 10 : 20
#   3:  10 : 10 : 36
#   4:  10 : 10 : 45
#   5:  10 : 10 : 25
#   6:  10 : 10 : 20
#   7:  10 : 10 : 65
#   8:  10 : 10 : 26
#   9:  10 : 10 : 25
#   10:  10 : 10 : 67
#   11:  10 : 10 : 67
#   12:  10 : 10 : 29
#   13:  10 : 10 : 28
#   14:  10 : 10 : 29
#   15:  10 : 10 : 21
#   16:  10 : 10 : 65
#   17:  10 : 10 : 62
#   18:  10 : 10 : 29
#   19:  10 : 10 : 36
#   20:  10 : 10 : 20
#   21:  10 : 10 : 39
#   22:  10 : 10 : 71
#   23:  10 : 10 : 22
#   24:  10 : 10 : 21
#   25:  10 : 10 : 21
#   26:  10 : 10 : 20
#   27:  10 : 10 : 46
#   28:  10 : 10 : 58
#   29:  10 : 10 : 65
#   30:  10 : 10 : 32
#   31:  10 : 10 : 25
#   32:  10 : 10 : 26
#   33:  10 : 10 : 20
#   34:  10 : 10 : 23
#   35:  10 : 10 : 55
#   36:  10 : 10 : 88
#   37:  10 : 10 : 36
#   38:  10 : 10 : 21
#   39:  10 : 10 : 47
#   40:  10 : 10 : 107
#   41:  10 : 10 : 39
#   42:  10 : 10 : 110
#   43:  10 : 10 : 73
#   44:  10 : 10 : 20
#   45:  10 : 10 : 176
#   46:  10 : 10 : 47
#   47:  10 : 10 : 51
#   48:  10 : 10 : 29
#   49:  10 : 10 : 72
#   50:  10 : 10 : 238
#   51:  10 : 10 : 65
#   52:  10 : 10 : 73
#   53:  10 : 10 : 41
#   54:  10 : 10 : 51
#   55:  10 : 10 : 89
#   56:  10 : 10 : 47
#   57:  10 : 10 : 94
#   58:  10 : 10 : 47
#   59:  10 : 10 : 89
#   60:  10 : 10 : 30
#   61:  10 : 10 : 35
#   62:  10 : 10 : 34
#   63:  10 : 10 : 32
#   64:  10 : 10 : 82
#   65:  10 : 10 : 41
#   66:  10 : 10 : 22
#   67:  10 : 10 : 34
#   68:  10 : 10 : 34
#   69:  10 : 10 : 42
#   70:  10 : 10 : 58
#   71:  10 : 10 : 76
#   72:  10 : 10 : 174
#   73:  10 : 10 : 151
#   74:  10 : 10 : 100
#   75:  10 : 10 : 87
#   76:  10 : 10 : 231
#   77:  10 : 10 : 117
#   78:  10 : 10 : 21
#   79:  10 : 10 : 85
#   80:  10 : 10 : 146
#   81:  10 : 10 : 92
#   82:  10 : 10 : 111
#   83:  10 : 10 : 66
#   84:  10 : 10 : 43
#   85:  10 : 10 : 38
#   86:  10 : 10 : 43
#   87:  10 : 10 : 134
#   88:  10 : 10 : 164
#   89:  10 : 10 : 62
#   90:  10 : 10 : 56
#   91:  10 : 10 : 46
#   92:  10 : 10 : 26
#   93:  10 : 10 : 142
#   94:  10 : 10 : 108
#   95:  10 : 10 : 71
#   96:  10 : 10 : 46
#   97:  10 : 10 : 62
#   98:  10 : 10 : 43
#   99:  10 : 10 : 29
#   100:  10 : 10 : 38
#   101:  10 : 10 : 28

# %%
plot_train_val_batches([train_loader, val_loader, test_loader], invTrans, 1)

# %%
num_classes = 102
model = torchvision.models.resnet50(pretrained=True)
model.fc = torch.nn.Linear(model.fc.in_features, num_classes)
model = model.to(device)

# count trainable params
num_trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print('total params for finetuning entire network: ', num_trainable_params)


# Training setting and Hyperparameters
epochs = 50
lr = 1e-4
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = lr)
patience = 5

# CyclicLR scheduler -> applied after every batch
    # My train dataset has len ~1020 and with bs = 32 => 30 iterations per epoch =>  50 epochs means a total of 1500 iterations 
    # Keep cycle of 2 epochs ~ 60 => step_size_up = 30

base_lr = 5e-6
max_lr = 5e-4
step_size_up = 30
mode = 'exp_range'

plot_lr_schedule(base_lr, max_lr, step_size_up, epochs, num_minibatches_per_epoch=30, mode = 'exp_range')

scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer, base_lr=base_lr, max_lr=max_lr, step_size_up=step_size_up, 
    mode=mode, gamma = 0.9994,cycle_momentum=False, base_momentum=0.8, max_momentum=0.9)
# Out:
# total params for finetuning entire network:  23717030

# %%
# train the model
tag = 'rn50_best_v2'
train_supervised(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs, patience, tag, device)
# Out:
# Validation loss decreased (inf --> 2.213243).  Saving model ...
# Epoch 1/50  Time: 22.35726237297058 sec
# Training Loss: 3.9630,   Training Accuracy: 0.1824
# Validation Loss: 2.2132, Validation Accuracy: 0.4608
#
# Validation loss decreased (2.213243 --> 1.064630).  Saving model ...
# Epoch 2/50  Time: 22.431214809417725 sec
# Training Loss: 1.3255,   Training Accuracy: 0.7902
# Validation Loss: 1.0646, Validation Accuracy: 0.8343
#
# Validation loss decreased (1.064630 --> 0.895744).  Saving model ...
# Epoch 3/50  Time: 22.444521188735962 sec
# Training Loss: 0.4203,   Training Accuracy: 0.9667
# Validation Loss: 0.8957, Validation Accuracy: 0.8020
#
# Validation loss decreased (0.895744 --> 0.527987).  Saving model ...
# Epoch 4/50  Time: 22.374984741210938 sec
# Training Loss: 0.1379,   Training Accuracy: 0.9892
# Validation Loss: 0.5280, Validation Accuracy: 0.8961
#
# EarlyStopping counter: 1 out of 5
# Epoch 5/50  Time: 22.675719499588013 sec
# Training Loss: 0.0558,   Training Accuracy: 0.9980
# Validation Loss: 0.5429, Validation Accuracy: 0.8755
#
# Validation loss decreased (0.527987 --> 0.458656).  Saving model ...
# Epoch 6/50  Time: 22.774813413619995 sec
# Training Loss: 0.0475,   Training Accuracy: 0.9922
# Validation Loss: 0.4587, Validation Accuracy: 0.9020
#
# EarlyStopping counter: 1 out of 5
# Epoch 7/50  Time: 22.334916830062866 sec
# Training Loss: 0.0299,   Training Accuracy: 0.9980
# Validation Loss: 0.4669, Validation Accuracy: 0.8971
#
# Validation loss decreased (0.458656 --> 0.405949).  Saving model ...
# Epoch 8/50  Time: 22.122563123703003 sec
# Training Loss: 0.0180,   Training Accuracy: 1.0000
# Validation Loss: 0.4059, Validation Accuracy: 0.9049
#
# Validation loss decreased (0.405949 --> 0.390650).  Saving model ...
# Epoch 9/50  Time: 22.475598335266113 sec
# Training Loss: 0.0110,   Training Accuracy: 1.0000
# Validation Loss: 0.3907, Validation Accuracy: 0.9108
#
# Validation loss decreased (0.390650 --> 0.371972).  Saving model ...
# Epoch 10/50  Time: 22.222338914871216 sec
# Training Loss: 0.0072,   Training Accuracy: 1.0000
# Validation Loss: 0.3720, Validation Accuracy: 0.9186
#
# Validation loss decreased (0.371972 --> 0.351368).  Saving model ...
# Epoch 11/50  Time: 22.380582094192505 sec
# Training Loss: 0.0063,   Training Accuracy: 1.0000
# Validation Loss: 0.3514, Validation Accuracy: 0.9255
#
# EarlyStopping counter: 1 out of 5
# Epoch 12/50  Time: 22.086237907409668 sec
# Training Loss: 0.0058,   Training Accuracy: 1.0000
# Validation Loss: 0.3528, Validation Accuracy: 0.9245
#
# EarlyStopping counter: 2 out of 5
# Epoch 13/50  Time: 22.03926157951355 sec
# Training Loss: 0.0052,   Training Accuracy: 1.0000
# Validation Loss: 0.3611, Validation Accuracy: 0.9137
#
# Validation loss decreased (0.351368 --> 0.340705).  Saving model ...
# Epoch 14/50  Time: 21.83310031890869 sec
# Training Loss: 0.0048,   Training Accuracy: 1.0000
# Validation Loss: 0.3407, Validation Accuracy: 0.9225
#
# EarlyStopping counter: 1 out of 5
# Epoch 15/50  Time: 22.157889127731323 sec
# Training Loss: 0.0046,   Training Accuracy: 1.0000
# Validation Loss: 0.3421, Validation Accuracy: 0.9225
#
# Validation loss decreased (0.340705 --> 0.330725).  Saving model ...
# Epoch 16/50  Time: 22.257630586624146 sec
# Training Loss: 0.0035,   Training Accuracy: 1.0000
# Validation Loss: 0.3307, Validation Accuracy: 0.9216
#
# Validation loss decreased (0.330725 --> 0.319049).  Saving model ...
# Epoch 17/50  Time: 22.204726457595825 sec
# Training Loss: 0.0029,   Training Accuracy: 1.0000
# Validation Loss: 0.3190, Validation Accuracy: 0.9294
#
# EarlyStopping counter: 1 out of 5
# Epoch 18/50  Time: 22.36880111694336 sec
# Training Loss: 0.0037,   Training Accuracy: 1.0000
# Validation Loss: 0.3255, Validation Accuracy: 0.9255
#
# EarlyStopping counter: 2 out of 5
# Epoch 19/50  Time: 21.967536687850952 sec
# Training Loss: 0.0028,   Training Accuracy: 1.0000
# Validation Loss: 0.3198, Validation Accuracy: 0.9216
#
# EarlyStopping counter: 3 out of 5
# Epoch 20/50  Time: 21.793738842010498 sec
# Training Loss: 0.0030,   Training Accuracy: 1.0000
# Validation Loss: 0.3231, Validation Accuracy: 0.9265
#
# Validation loss decreased (0.319049 --> 0.318714).  Saving model ...
# Epoch 21/50  Time: 22.416462898254395 sec
# Training Loss: 0.0023,   Training Accuracy: 1.0000
# Validation Loss: 0.3187, Validation Accuracy: 0.9255
#
# Validation loss decreased (0.318714 --> 0.308315).  Saving model ...
# Epoch 22/50  Time: 23.143933296203613 sec
# Training Loss: 0.0022,   Training Accuracy: 1.0000
# Validation Loss: 0.3083, Validation Accuracy: 0.9265
#
# EarlyStopping counter: 1 out of 5
# Epoch 23/50  Time: 23.264978885650635 sec
# Training Loss: 0.0020,   Training Accuracy: 1.0000
# Validation Loss: 0.3136, Validation Accuracy: 0.9284
#
# EarlyStopping counter: 2 out of 5
# Epoch 24/50  Time: 22.70272445678711 sec
# Training Loss: 0.0018,   Training Accuracy: 1.0000
# Validation Loss: 0.3142, Validation Accuracy: 0.9275
#
# EarlyStopping counter: 3 out of 5
# Epoch 25/50  Time: 22.187819004058838 sec
# Training Loss: 0.0018,   Training Accuracy: 1.0000
# Validation Loss: 0.3139, Validation Accuracy: 0.9245
#
# Validation loss decreased (0.308315 --> 0.301358).  Saving model ...
# Epoch 26/50  Time: 22.07948112487793 sec
# Training Loss: 0.0017,   Training Accuracy: 1.0000
# Validation Loss: 0.3014, Validation Accuracy: 0.9284
#
# EarlyStopping counter: 1 out of 5
# Epoch 27/50  Time: 22.75861144065857 sec
# Training Loss: 0.0014,   Training Accuracy: 1.0000
# Validation Loss: 0.3078, Validation Accuracy: 0.9265
#
# Validation loss decreased (0.301358 --> 0.298365).  Saving model ...
# Epoch 28/50  Time: 22.14597201347351 sec
# Training Loss: 0.0016,   Training Accuracy: 1.0000
# Validation Loss: 0.2984, Validation Accuracy: 0.9294
#
# Validation loss decreased (0.298365 --> 0.296658).  Saving model ...
# Epoch 29/50  Time: 22.283681631088257 sec
# Training Loss: 0.0014,   Training Accuracy: 1.0000
# Validation Loss: 0.2967, Validation Accuracy: 0.9294
#
# Validation loss decreased (0.296658 --> 0.291626).  Saving model ...
# Epoch 30/50  Time: 22.35951280593872 sec
# Training Loss: 0.0013,   Training Accuracy: 1.0000
# Validation Loss: 0.2916, Validation Accuracy: 0.9324
#
# EarlyStopping counter: 1 out of 5
# Epoch 31/50  Time: 22.123011589050293 sec
# Training Loss: 0.0013,   Training Accuracy: 1.0000
# Validation Loss: 0.2932, Validation Accuracy: 0.9275
#
# EarlyStopping counter: 2 out of 5
# Epoch 32/50  Time: 22.514716625213623 sec
# Training Loss: 0.0012,   Training Accuracy: 1.0000
# Validation Loss: 0.3013, Validation Accuracy: 0.9265
#
# EarlyStopping counter: 3 out of 5
# Epoch 33/50  Time: 22.209550142288208 sec
# Training Loss: 0.0012,   Training Accuracy: 1.0000
# Validation Loss: 0.2963, Validation Accuracy: 0.9314
#
# EarlyStopping counter: 4 out of 5
# Epoch 34/50  Time: 22.231449842453003 sec
# Training Loss: 0.0010,   Training Accuracy: 1.0000
# Validation Loss: 0.3012, Validation Accuracy: 0.9284
#
# EarlyStopping counter: 5 out of 5
# Epoch 35/50  Time: 22.154909133911133 sec
# Training Loss: 0.0011,   Training Accuracy: 1.0000
# Validation Loss: 0.2958, Validation Accuracy: 0.9294
#
# Early stopping

# %%
# Evaluate performance on test set
model = torch.load('rn50_best_v2.pth')
model = model.to(device)
test_model(model, test_loader, criterion)
# Out:
# Test Loss: 0.3946, Test Accuracy: 0.9060

# %% [markdown]
# ####  > Baseline: 90.6.00% : no augmentations

# %% [markdown]
# Until now we have not used augmentations and number of training images are only 10 per class. With such minimal dataset, we acheived ~ 90.6% accuracy - Not bad!
#
# __Let's see if we can further improve it by including image augmentations.__

# %%
train_transform = transforms.Compose([
    transforms.RandomResizedCrop((224, 224), scale = (0.7, 1.0), ratio = (0.85, 1.15)),
    transforms.RandomHorizontalFlip(p=0.3),
    transforms.RandomVerticalFlip(p=0.3),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
train_ds = FlowerDataset(pths = train_files, targets= train_labels, transform=train_transform)
val_ds = FlowerDataset(val_files, val_labels, transform=test_transform) # let's apply same augmentations to val set to make it a bit more difficult
test_ds = FlowerDataset(test_files, test_labels, transform=test_transform)

bs = 32

train_loader = DataLoader(train_ds, batch_size = bs, shuffle = True)
val_loader = DataLoader(val_ds, batch_size = bs, shuffle = False)
test_loader = DataLoader(test_ds, batch_size = bs, shuffle = False)

X, y = next(iter(train_loader))
print(X.shape, y.shape)

plot_train_val_batches([train_loader, val_loader, test_loader], invTrans, 2)
# Out:
# torch.Size([32, 3, 224, 224]) torch.Size([32])

# %%
num_classes = 102
model = torchvision.models.resnet50(pretrained=True)
model.fc = torch.nn.Linear(model.fc.in_features, num_classes)
model = model.to(device)

# count trainable params
num_trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print('total params for finetuning entire network: ', num_trainable_params)


# Training setting and Hyperparameters
epochs = 200
lr = 1e-4
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = lr)
patience = 5

# CyclicLR scheduler -> applied after every batch
    # My train dataset has len ~1020 and with bs = 32 => 30 iterations per epoch =>  200 epochs means a total of 6000 iterations 
    # Keep cycle of 4 epochs ~ 60 => step_size_up = 30

base_lr = 5e-6
max_lr = 5e-4
step_size_up = 60
mode = 'exp_range'

plot_lr_schedule(base_lr, max_lr, step_size_up, epochs, num_minibatches_per_epoch=30, mode = 'exp_range')

scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer, base_lr=base_lr, max_lr=max_lr, step_size_up=step_size_up, 
    mode=mode, gamma = 0.9994,cycle_momentum=False, base_momentum=0.8, max_momentum=0.9)

# train the model
tag = 'rn50_best_v2_aug'
train_supervised(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs, patience, tag, device)
# Out:
# C:\Users\mgupta70.ASURITE\.conda\envs\kerastens\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\mgupta70.ASURITE\.conda\envs\kerastens\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# total params for finetuning entire network:  23717030
# Validation loss decreased (inf --> 2.339283).  Saving model ...
# Epoch 1/200  Time: 23.128939867019653 sec
# Training Loss: 3.9566,   Training Accuracy: 0.1931
# Validation Loss: 2.3393, Validation Accuracy: 0.4686
#
# Validation loss decreased (2.339283 --> 1.077270).  Saving model ...
# Epoch 2/200  Time: 23.201257467269897 sec
# Training Loss: 1.5078,   Training Accuracy: 0.7265
# Validation Loss: 1.0773, Validation Accuracy: 0.8294
#
# EarlyStopping counter: 1 out of 5
# Epoch 3/200  Time: 23.035760641098022 sec
# Training Loss: 0.7057,   Training Accuracy: 0.8990
# Validation Loss: 1.1720, Validation Accuracy: 0.7314
#
# Validation loss decreased (1.077270 --> 0.476333).  Saving model ...
# Epoch 4/200  Time: 23.137908220291138 sec
# Training Loss: 0.3429,   Training Accuracy: 0.9559
# Validation Loss: 0.4763, Validation Accuracy: 0.8971
#
# EarlyStopping counter: 1 out of 5
# Epoch 5/200  Time: 23.723289728164673 sec
# Training Loss: 0.1716,   Training Accuracy: 0.9794
# Validation Loss: 0.7291, Validation Accuracy: 0.8225
#
# Validation loss decreased (0.476333 --> 0.408423).  Saving model ...
# Epoch 6/200  Time: 22.718682765960693 sec
# Training Loss: 0.1638,   Training Accuracy: 0.9745
# Validation Loss: 0.4084, Validation Accuracy: 0.9088
#
# EarlyStopping counter: 1 out of 5
# Epoch 7/200  Time: 23.07550621032715 sec
# Training Loss: 0.1020,   Training Accuracy: 0.9853
# Validation Loss: 0.5854, Validation Accuracy: 0.8627
#
# Validation loss decreased (0.408423 --> 0.361757).  Saving model ...
# Epoch 8/200  Time: 22.858988046646118 sec
# Training Loss: 0.0772,   Training Accuracy: 0.9902
# Validation Loss: 0.3618, Validation Accuracy: 0.9157
#
# EarlyStopping counter: 1 out of 5
# Epoch 9/200  Time: 22.918755531311035 sec
# Training Loss: 0.0586,   Training Accuracy: 0.9902
# Validation Loss: 0.4523, Validation Accuracy: 0.8912
#
# EarlyStopping counter: 2 out of 5
# Epoch 10/200  Time: 22.802437782287598 sec
# Training Loss: 0.0619,   Training Accuracy: 0.9922
# Validation Loss: 0.3740, Validation Accuracy: 0.9157
#
# EarlyStopping counter: 3 out of 5
# Epoch 11/200  Time: 23.393486261367798 sec
# Training Loss: 0.0544,   Training Accuracy: 0.9922
# Validation Loss: 0.4302, Validation Accuracy: 0.9029
#
# EarlyStopping counter: 4 out of 5
# Epoch 12/200  Time: 22.637858390808105 sec
# Training Loss: 0.0424,   Training Accuracy: 0.9922
# Validation Loss: 0.4605, Validation Accuracy: 0.8922
#
# EarlyStopping counter: 5 out of 5
# Epoch 13/200  Time: 22.623180150985718 sec
# Training Loss: 0.1596,   Training Accuracy: 0.9676
# Validation Loss: 0.7104, Validation Accuracy: 0.8255
#
# Early stopping

# %%
# Evaluate performance on test set
model = torch.load('rn50_best_v2_aug.pth')
model = model.to(device)
test_model(model, test_loader, criterion)
# Out:
# Test Loss: 0.4761, Test Accuracy: 0.8816

# %% [markdown]
# The performance didn't increase. It might depend on various hyperparameters like lr, lr_scheduler, batchsize, and augmentations we used. It might involve some hit-and-trials to get best hyperparameters.

# %% [markdown]
# There is another way to create augmentations - where we could create `n_augmentations` per image in training dataset. For this refer to <a href="https://github.com/mgupta70/code-blocks/blob/main/Image_classification/DL_Image_Augmentations.ipynb"> __this notebook__ </a> to see how it is done. I believe this should give more or less the similar results becuase technically speaking, it is not very different than what we are doing here.

# %%
class FlowerDataset_v2(Dataset):
    ''' To increase the length of dataset with augmentations'''
    def __init__(self, im_pths, targets, num_augmentations, transform = None, target_transform = None):
        self.im_pths = im_pths
        self.targets = targets
        self.num_augmentations = num_augmentations
        self.transform = transform
        self.target_transform = target_transform
        
    def __len__(self):
        return len(self.im_pths)*self.num_augmentations
        
    def __getitem__(self, idx):
        actual_idx = idx // self.num_augmentations
        augmentation_idx = idx % self.num_augmentations
        
        im_pth = str(self.im_pths[actual_idx])
        image = Image.fromarray(cv2.cvtColor(cv2.imread(im_pth), cv2.COLOR_BGR2RGB))
        label = self.targets[actual_idx]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %%
train_ds = FlowerDataset_v2(train_files, train_labels, num_augmentations=5, transform=train_transform)
val_ds = FlowerDataset_v2(val_files, val_labels, num_augmentations=5, transform=train_transform) # let's apply same augmentations to val set to make it ensure training is more gener
test_ds = FlowerDataset_v2(test_files, test_labels, num_augmentations=1, transform=test_transform) # DO NOT MODIFY THIS

bs = 32

train_loader = DataLoader(train_ds, batch_size = bs, shuffle = True)
val_loader = DataLoader(val_ds, batch_size = bs, shuffle = False)
test_loader = DataLoader(test_ds, batch_size = bs, shuffle = False)

X, y = next(iter(train_loader))
print(X.shape, y.shape)

plot_train_val_batches([train_loader, val_loader, test_loader], invTrans, 2)
# Out:
# torch.Size([32, 3, 224, 224]) torch.Size([32])

# %%
num_classes = 102
model = torchvision.models.resnet50(pretrained=True)
model.fc = torch.nn.Linear(model.fc.in_features, num_classes)
model = model.to(device)

# count trainable params
num_trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print('total params for finetuning entire network: ', num_trainable_params)


# Training setting and Hyperparameters
epochs = 50
lr = 1e-4
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = lr)
patience = 5

# CyclicLR scheduler -> applied after every batch
    # My train dataset has len ~1020*5 and with bs = 32 => 150 iterations per epoch 
    # Keep cycle of 2 epochs ~ 300 => step_size_up = 150

base_lr = 5e-6
max_lr = 5e-4
step_size_up = 150
mode = 'exp_range'

plot_lr_schedule(base_lr, max_lr, step_size_up, epochs, num_minibatches_per_epoch=30, mode = 'exp_range')

scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer, base_lr=base_lr, max_lr=max_lr, step_size_up=step_size_up, 
    mode=mode, gamma = 0.9994,cycle_momentum=False, base_momentum=0.8, max_momentum=0.9)

# train the model
tag = 'rn50_best_v3_aug'
train_supervised(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs, patience, tag, device)
# Out:
# total params for finetuning entire network:  23717030
# Validation loss decreased (inf --> 1.356103).  Saving model ...
# Epoch 1/50  Time: 117.98242688179016 sec
# Training Loss: 1.9789,   Training Accuracy: 0.6469
# Validation Loss: 1.3561, Validation Accuracy: 0.6682
#
# Validation loss decreased (1.356103 --> 0.363321).  Saving model ...
# Epoch 2/50  Time: 120.79080891609192 sec
# Training Loss: 0.2012,   Training Accuracy: 0.9596
# Validation Loss: 0.3633, Validation Accuracy: 0.9090
#
# EarlyStopping counter: 1 out of 5
# Epoch 3/50  Time: 117.86072731018066 sec
# Training Loss: 0.0252,   Training Accuracy: 0.9982
# Validation Loss: 0.5718, Validation Accuracy: 0.8576
#
# Validation loss decreased (0.363321 --> 0.344891).  Saving model ...
# Epoch 4/50  Time: 119.41669130325317 sec
# Training Loss: 0.0424,   Training Accuracy: 0.9931
# Validation Loss: 0.3449, Validation Accuracy: 0.9159
#
# EarlyStopping counter: 1 out of 5
# Epoch 5/50  Time: 116.64527082443237 sec
# Training Loss: 0.0616,   Training Accuracy: 0.9890
# Validation Loss: 1.0005, Validation Accuracy: 0.7694
#
# EarlyStopping counter: 2 out of 5
# Epoch 6/50  Time: 117.48340225219727 sec
# Training Loss: 0.0672,   Training Accuracy: 0.9855
# Validation Loss: 0.4012, Validation Accuracy: 0.9010
#
# EarlyStopping counter: 3 out of 5
# Epoch 7/50  Time: 117.18437552452087 sec
# Training Loss: 0.0065,   Training Accuracy: 1.0000
# Validation Loss: 0.3454, Validation Accuracy: 0.9141
#
# Validation loss decreased (0.344891 --> 0.311474).  Saving model ...
# Epoch 8/50  Time: 118.35310697555542 sec
# Training Loss: 0.0035,   Training Accuracy: 1.0000
# Validation Loss: 0.3115, Validation Accuracy: 0.9229
#
# EarlyStopping counter: 1 out of 5
# Epoch 9/50  Time: 117.3903214931488 sec
# Training Loss: 0.0037,   Training Accuracy: 0.9998
# Validation Loss: 0.3208, Validation Accuracy: 0.9192
#
# Validation loss decreased (0.311474 --> 0.306873).  Saving model ...
# Epoch 10/50  Time: 117.36706113815308 sec
# Training Loss: 0.0033,   Training Accuracy: 0.9998
# Validation Loss: 0.3069, Validation Accuracy: 0.9220
#
# EarlyStopping counter: 1 out of 5
# Epoch 11/50  Time: 116.90558004379272 sec
# Training Loss: 0.0028,   Training Accuracy: 0.9996
# Validation Loss: 0.3258, Validation Accuracy: 0.9173
#
# EarlyStopping counter: 2 out of 5
# Epoch 12/50  Time: 115.39581274986267 sec
# Training Loss: 0.0020,   Training Accuracy: 1.0000
# Validation Loss: 0.3213, Validation Accuracy: 0.9235
#
# EarlyStopping counter: 3 out of 5
# Epoch 13/50  Time: 115.66542959213257 sec
# Training Loss: 0.0019,   Training Accuracy: 1.0000
# Validation Loss: 0.3281, Validation Accuracy: 0.9208
#
# Validation loss decreased (0.306873 --> 0.303185).  Saving model ...
# Epoch 14/50  Time: 118.65134572982788 sec
# Training Loss: 0.0012,   Training Accuracy: 1.0000
# Validation Loss: 0.3032, Validation Accuracy: 0.9304
#
# Validation loss decreased (0.303185 --> 0.287060).  Saving model ...
# Epoch 15/50  Time: 116.82092547416687 sec
# Training Loss: 0.0011,   Training Accuracy: 1.0000
# Validation Loss: 0.2871, Validation Accuracy: 0.9294
#
# EarlyStopping counter: 1 out of 5
# Epoch 16/50  Time: 118.93576073646545 sec
# Training Loss: 0.0013,   Training Accuracy: 1.0000
# Validation Loss: 0.3235, Validation Accuracy: 0.9200
#
# EarlyStopping counter: 2 out of 5
# Epoch 17/50  Time: 121.62366962432861 sec
# Training Loss: 0.0063,   Training Accuracy: 0.9992
# Validation Loss: 0.2917, Validation Accuracy: 0.9294
#
# EarlyStopping counter: 3 out of 5
# Epoch 18/50  Time: 119.79795002937317 sec
# Training Loss: 0.0021,   Training Accuracy: 0.9998
# Validation Loss: 0.2916, Validation Accuracy: 0.9292
#
# Validation loss decreased (0.287060 --> 0.263009).  Saving model ...
# Epoch 19/50  Time: 121.58120799064636 sec
# Training Loss: 0.0010,   Training Accuracy: 1.0000
# Validation Loss: 0.2630, Validation Accuracy: 0.9386
#
# Validation loss decreased (0.263009 --> 0.257875).  Saving model ...
# Epoch 20/50  Time: 118.28290390968323 sec
# Training Loss: 0.0009,   Training Accuracy: 1.0000
# Validation Loss: 0.2579, Validation Accuracy: 0.9390
#
# EarlyStopping counter: 1 out of 5
# Epoch 21/50  Time: 117.72248911857605 sec
# Training Loss: 0.0009,   Training Accuracy: 1.0000
# Validation Loss: 0.2872, Validation Accuracy: 0.9371
#
# Validation loss decreased (0.257875 --> 0.257730).  Saving model ...
# Epoch 22/50  Time: 117.98320126533508 sec
# Training Loss: 0.0008,   Training Accuracy: 1.0000
# Validation Loss: 0.2577, Validation Accuracy: 0.9412
#
# EarlyStopping counter: 1 out of 5
# Epoch 23/50  Time: 118.18725872039795 sec
# Training Loss: 0.0007,   Training Accuracy: 1.0000
# Validation Loss: 0.2587, Validation Accuracy: 0.9412
#
# EarlyStopping counter: 2 out of 5
# Epoch 24/50  Time: 119.90632224082947 sec
# Training Loss: 0.0006,   Training Accuracy: 1.0000
# Validation Loss: 0.2598, Validation Accuracy: 0.9414
#
# Validation loss decreased (0.257730 --> 0.255169).  Saving model ...
# Epoch 25/50  Time: 121.83218216896057 sec
# Training Loss: 0.0006,   Training Accuracy: 1.0000
# Validation Loss: 0.2552, Validation Accuracy: 0.9414
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 34
#      32 # train the model
#      33 tag = 'rn50_best_v3_aug'
# ---> 34 train_supervised(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs, patience, tag, device)
#
# File ~\ASU Dropbox\Mohit Gupta\ASU\PhD\Courses\Sem-7\fellowship_ai\utils.py:164, in train_supervised(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs, patience, tag, device)
#     161 val_corrects = 0
#     163 with torch.no_grad():
# --> 164     for inputs, labels in val_loader:
#     165         inputs, labels = inputs.to(device), labels.to(device)
#     166         logits = model(inputs)
#
# File ~\.conda\envs\kerastens\lib\site-packages\fastai\data\load.py:127, in DataLoader.__iter__(self)
#     125 self.before_iter()
#     126 self.__idxs=self.get_idxs() # called in context of main process (not workers/subprocesses)
# --> 127 for b in _loaders[self.fake_l.num_workers==0](self.fake_l):
#     128     # pin_memory causes tuples to be converted to lists, so convert them back to tuples
#     129     if self.pin_memory and type(b) == list: b = tuple(b)
#     130     if self.device is not None: b = to_device(b, self.device)
#
# File ~\.conda\envs\kerastens\lib\site-packages\torch\utils\data\dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\.conda\envs\kerastens\lib\site-packages\torch\utils\data\dataloader.py:671, in _SingleProcessDataLoaderIter._next_data(self)
#     669 def _next_data(self):
#     670     index = self._next_index()  # may raise StopIteration
# --> 671     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672     if self._pin_memory:
#     673         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\.conda\envs\kerastens\lib\site-packages\torch\utils\data\_utils\fetch.py:43, in _IterableDatasetFetcher.fetch(self, possibly_batched_index)
#      41         raise StopIteration
#      42 else:
# ---> 43     data = next(self.dataset_iter)
#      44 return self.collate_fn(data)
#
# File ~\.conda\envs\kerastens\lib\site-packages\fastai\data\load.py:138, in DataLoader.create_batches(self, samps)
#     136 if self.dataset is not None: self.it = iter(self.dataset)
#     137 res = filter(lambda o:o is not None, map(self.do_item, samps))
# --> 138 yield from map(self.do_batch, self.chunkify(res))
#
# File ~\.conda\envs\kerastens\lib\site-packages\fastcore\basics.py:230, in chunked(it, chunk_sz, drop_last, n_chunks)
#     228 if not isinstance(it, Iterator): it = iter(it)
#     229 while True:
# --> 230     res = list(itertools.islice(it, chunk_sz))
#     231     if res and (len(res)==chunk_sz or not drop_last): yield res
#     232     if len(res)<chunk_sz: return
#
# File ~\.conda\envs\kerastens\lib\site-packages\fastai\data\load.py:153, in DataLoader.do_item(self, s)
#     152 def do_item(self, s):
# --> 153     try: return self.after_item(self.create_item(s))
#     154     except SkipItemException: return None
#
# File ~\.conda\envs\kerastens\lib\site-packages\fastai\data\load.py:160, in DataLoader.create_item(self, s)
#     159 def create_item(self, s):
# --> 160     if self.indexed: return self.dataset[s or 0]
#     161     elif s is None:  return next(self.it)
#     162     else: raise IndexError("Cannot index an iterable dataset numerically - must use `None`.")
#
# Cell In[33], line 18, in FlowerDataset2.__getitem__(self, idx)
#      15 augmentation_idx = idx % self.num_augmentations
#      17 im_pth = str(self.im_pths[actual_idx])
# ---> 18 image = Image.fromarray(cv2.cvtColor(cv2.imread(im_pth), cv2.COLOR_BGR2RGB))
#      19 label = self.targets[actual_idx]
#      20 if self.transform:
#
# KeyboardInterrupt:

# %%
# Evaluate performance on test set
model = torch.load('rn50_best_v3_aug.pth')
model = model.to(device)
test_model(model, test_loader, criterion)
# Out:
# Test Loss: 0.3663, Test Accuracy: 0.9057

# %% [markdown]
# __Other option__ - Since we have only 10 images for training and 10 for validation, may be it is a good idea to explore few-shot learning
#
# Refer <a href="https://github.com/mgupta70/code-blocks/blob/main/fellowship/flower_classification_few_shot_learning.ipynb"> __this notebook__ </a> for it - Although I did not get better results while training a Protoypical Network for it.
